# %%
# !pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/40.2 MB ? eta -:--:--
#     --------------------------------------- 0.5/40.2 MB 1.2 MB/s eta 0:00:33
#    - -------------------------------------- 1.0/40.2 MB 1.6 MB/s eta 0:00:25
#    - -------------------------------------- 1.6/40.2 MB 1.8 MB/s eta 0:00:22
#    - -------------------------------------- 1.6/40.2 MB 1.8 MB/s eta 0:00:22
#    -- ------------------------------------- 2.1/40.2 MB 1.7 MB/s eta 0:00:23
#    -- ------------------------------------- 2.6/40.2 MB 1.8 MB/s eta 0:00:21
#    --- ------------------------------------ 3.4/40.2 MB 2.0 MB/s eta 0:00:18
#    --- ------------------------------------ 3.7/40.2 MB 2.1 MB/s eta 0:00:18
#    ---- ----------------------------------- 4.2/40.2 MB 2.0 MB/s eta 0:00:18
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('l1.jpeg')
b, g, r = cv2.split(img)

plt.subplot(1,3,1), plt.imshow(r, cmap='Reds')
plt.title('Red Channel')

plt.subplot(1,3,2), plt.imshow(g, cmap='Greens')
plt.title('Green Channel')

plt.subplot(1,3,3), plt.imshow(b, cmap='Blues')
plt.title('Blue Channel')

plt.show()
